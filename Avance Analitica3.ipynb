# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.express as px

# %% [markdown]
# # Limpieza

# %% [markdown]
# ## general_data.csv

# %%
empleados=pd.read_csv(r'D:\Usuario\Desktop\Analitica 3\general_data.csv',sep=';')

# %%
for i in empleados.columns:
    print(i,empleados[i].isnull().value_counts())
# Out:
# Age False    4410
# Name: Age, dtype: int64
# BusinessTravel False    4410
# Name: BusinessTravel, dtype: int64
# Department False    4410
# Name: Department, dtype: int64
# DistanceFromHome False    4410
# Name: DistanceFromHome, dtype: int64
# Education False    4410
# Name: Education, dtype: int64
# EducationField False    4410
# Name: EducationField, dtype: int64
# EmployeeCount False    4410
# Name: EmployeeCount, dtype: int64
# EmployeeID False    4410
# Name: EmployeeID, dtype: int64
# Gender False    4410
# Name: Gender, dtype: int64
# JobLevel False    4410
# Name: JobLevel, dtype: int64
# JobRole False    4410
# Name: JobRole, dtype: int64
# MaritalStatus False    4410
# Name: MaritalStatus, dtype: int64
# MonthlyIncome False    4410
# Name: MonthlyIncome, dtype: int64
# NumCompaniesWorked False    4391
# True       19
# Name: NumCompaniesWorked, dtype: int64
# Over18 False    4410
# Name: Over18, dtype: int64
# PercentSalaryHike False    4410
# ...

# %%
#CAD 1
toReplace=['NumCompaniesWorked','TotalWorkingYears']
for i in toReplace:
    empleados[i].replace(np.nan,0,inplace=True)

for i in empleados.columns:
    print(i,empleados[i].isnull().value_counts())
# Out:
# Age False    4410
# Name: Age, dtype: int64
# BusinessTravel False    4410
# Name: BusinessTravel, dtype: int64
# Department False    4410
# Name: Department, dtype: int64
# DistanceFromHome False    4410
# Name: DistanceFromHome, dtype: int64
# Education False    4410
# Name: Education, dtype: int64
# EducationField False    4410
# Name: EducationField, dtype: int64
# EmployeeCount False    4410
# Name: EmployeeCount, dtype: int64
# EmployeeID False    4410
# Name: EmployeeID, dtype: int64
# Gender False    4410
# Name: Gender, dtype: int64
# JobLevel False    4410
# Name: JobLevel, dtype: int64
# JobRole False    4410
# Name: JobRole, dtype: int64
# MaritalStatus False    4410
# Name: MaritalStatus, dtype: int64
# MonthlyIncome False    4410
# Name: MonthlyIncome, dtype: int64
# NumCompaniesWorked False    4410
# Name: NumCompaniesWorked, dtype: int64
# Over18 False    4410
# Name: Over18, dtype: int64
# PercentSalaryHike False    4410
# Name: PercentSalaryHike, dtype: int64
# ...

# %% [markdown]
# ## employee_survey_data.csv

# %%
satisfaccion=pd.read_csv(r'D:\Usuario\Desktop\Analitica 3\employee_survey_data.csv')
satisfaccion
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# [4410 rows x 4 columns]

# %%
for i in satisfaccion.columns:
    print(i,satisfaccion[i].isnull().value_counts())
# Out:
# EmployeeID False    4410
# Name: EmployeeID, dtype: int64
# EnvironmentSatisfaction False    4385
# True       25
# Name: EnvironmentSatisfaction, dtype: int64
# JobSatisfaction False    4390
# True       20
# Name: JobSatisfaction, dtype: int64
# WorkLifeBalance False    4372
# True       38
# Name: WorkLifeBalance, dtype: int64

# %%
satisfaccion[satisfaccion['WorkLifeBalance'].isnull()]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 84            85                      3.0              4.0              NaN
# 273          274                      3.0              4.0              NaN
# 483          484                      4.0              3.0              NaN
# 609          610                      4.0              1.0              NaN
# 735          736                      1.0              3.0              NaN
# 861          862                      3.0              2.0              NaN
# 987          988                      1.0              4.0              NaN
# 1092        1093                      1.0              3.0              NaN
# 1197        1198                      3.0              3.0              NaN
# 1260        1261                      1.0              4.0              NaN
# 1323        1324                      1.0              3.0              NaN
# ...

# %%
satisfaccion[satisfaccion['EnvironmentSatisfaction'].isnull()]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 11            12                      NaN              4.0              3.0
# 111          112                      NaN              2.0              3.0
# 195          196                      NaN              3.0              2.0
# 300          301                      NaN              4.0              3.0
# 405          406                      NaN              4.0              2.0
# 489          490                      NaN              4.0              3.0
# 678          679                      NaN              2.0              3.0
# 846          847                      NaN              3.0              2.0
# 909          910                      NaN              4.0              2.0
# 1077        1078                      NaN              4.0              3.0
# 1224        1225                      NaN              3.0              2.0
# ...

# %%
satisfaccion[satisfaccion['JobSatisfaction'].isnull()]
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 40            41                      3.0              NaN              3.0
# 124          125                      3.0              NaN              3.0
# 313          314                      1.0              NaN              3.0
# 586          587                      3.0              NaN              3.0
# 859          860                      2.0              NaN              2.0
# 1195        1196                      2.0              NaN              2.0
# 1468        1469                      4.0              NaN              3.0
# 1678        1679                      2.0              NaN              3.0
# 1909        1910                      3.0              NaN              3.0
# 2182        2183                      3.0              NaN              3.0
# 2476        2477                      3.0              NaN              3.0
# ...

# %%
#CAD 2
mediaES=satisfaccion['EnvironmentSatisfaction'][satisfaccion['EnvironmentSatisfaction'].notnull()].mean().__round__(2)
mediaJS=satisfaccion['JobSatisfaction'][satisfaccion['JobSatisfaction'].notnull()].mean().__round__(2)
mediaWLB=satisfaccion['WorkLifeBalance'][satisfaccion['WorkLifeBalance'].notnull()].mean().__round__(2)
medias=[mediaES,mediaJS,mediaWLB]
for i,j in zip(satisfaccion.columns[1:],medias):
    satisfaccion[i].replace(np.nan,j,inplace=True)

# %%
for i in satisfaccion.columns:
    print(i,satisfaccion[i].isnull().value_counts())
# Out:
# EmployeeID False    4410
# Name: EmployeeID, dtype: int64
# EnvironmentSatisfaction False    4410
# Name: EnvironmentSatisfaction, dtype: int64
# JobSatisfaction False    4410
# Name: JobSatisfaction, dtype: int64
# WorkLifeBalance False    4410
# Name: WorkLifeBalance, dtype: int64

# %% [markdown]
# ## retirement_info.csv

# %%
retiros=pd.read_csv(r'D:\Usuario\Desktop\Analitica 3\retirement_info.csv',sep=';')
retiros
# Out:
#      EmployeeID Attrition retirementDate retirementType resignationReason
# 0             2       Yes     15/10/2016    Resignation            Others
# 1             7       Yes     20/07/2016    Resignation            Stress
# 2            14       Yes     08/11/2016    Resignation            Others
# 3            29       Yes     15/10/2016    Resignation            Others
# 4            31       Yes     08/02/2016    Resignation            Salary
# ..          ...       ...            ...            ...               ...
# 706        4382       Yes     18/04/2016    Resignation            Salary
# 707        4387       Yes     16/09/2016    Resignation            Others
# 708        4389       Yes     24/05/2016    Resignation            Others
# 709        4392       Yes     26/02/2016          Fired               NaN
# 710        4403       Yes     26/01/2016    Resignation            Stress
#
# [711 rows x 5 columns]

# %%
for i in retiros.columns:
    print(i,retiros[i].isnull().value_counts())
# Out:
# EmployeeID False    711
# Name: EmployeeID, dtype: int64
# Attrition False    711
# Name: Attrition, dtype: int64
# retirementDate False    711
# Name: retirementDate, dtype: int64
# retirementType False    711
# Name: retirementType, dtype: int64
# resignationReason False    641
# True      70
# Name: resignationReason, dtype: int64

# %%
#CAD 3
retiros['resignationReason'].replace(np.nan,'NR',inplace=True)

# %% [markdown]
# ## manager_survey_data.csv

# %%
managers=pd.read_csv(r'D:\Usuario\Desktop\Analitica 3\manager_survey_data.csv')
managers
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating
# 0              1               3                  3
# 1              2               2                  4
# 2              3               3                  3
# 3              4               2                  3
# 4              5               3                  3
# ...          ...             ...                ...
# 4405        4406               3                  3
# 4406        4407               2                  3
# 4407        4408               3                  4
# 4408        4409               2                  3
# 4409        4410               4                  3
#
# [4410 rows x 3 columns]

# %%
for i in managers.columns:
    print(i,managers[i].isnull().value_counts())
# Out:
# EmployeeID False    4410
# Name: EmployeeID, dtype: int64
# JobInvolvement False    4410
# Name: JobInvolvement, dtype: int64
# PerformanceRating False    4410
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# ## In n Out Times

# %%
in_time=pd.read_csv(r'C:\Users\PC\Desktop\Analitica 3\in_time.csv')
in_time
# Out:
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0              1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1              2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2              3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3              4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4              5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
# ...          ...         ...                  ...                  ...
# 4405        4406         NaN  2015-01-02 09:20:32  2015-01-05 10:17:53
# 4406        4407         NaN  2015-01-02 10:03:41                  NaN
# 4407        4408         NaN  2015-01-02 10:01:01  2015-01-05 09:33:00
# 4408        4409         NaN  2015-01-02 10:17:05  2015-01-05 10:02:27
# 4409        4410         NaN  2015-01-02 09:59:09  2015-01-05 10:16:14
#
#                2015-01-06           2015-01-07           2015-01-08  \
# ...

# %%
out_time=pd.read_csv(r'C:\Users\PC\Desktop\Analitica 3\out_time.csv')
out_time
# Out:
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0              1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1              2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2              3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3              4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4              5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
# ...          ...         ...                  ...                  ...
# 4405        4406         NaN  2015-01-02 17:27:37  2015-01-05 19:08:20
# 4406        4407         NaN  2015-01-02 16:19:01                  NaN
# 4407        4408         NaN  2015-01-02 17:17:35  2015-01-05 17:08:07
# 4408        4409         NaN  2015-01-02 19:48:37  2015-01-05 19:37:40
# 4409        4410         NaN  2015-01-02 16:49:19  2015-01-05 17:33:02
#
#                2015-01-06           2015-01-07           2015-01-08  \
# ...

# %% [markdown]
# # Graficas

# %% [markdown]
# Tortas para comportamiento de las personas que renuncian
# Sacar quantiles de MonthlyIncome
# Multiplicar PercentSalaryHike por 1/100
# Aclarar que es StockOptionLevel

# %%
empleados.columns
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
borrar=['EmployeeCount','Over18','StandardHours']
# Out:
# array([1], dtype=int64)

# %%
managers.columns
# Out:
# Index(['EmployeeID', 'JobInvolvement', 'PerformanceRating'], dtype='object')

# %%
managers.PerformanceRating.unique()
# Out:
# array([3, 4], dtype=int64)

# %%
satisfaccion.columns
# Out:
# Index(['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance'],
#       dtype='object')

# %%
satisfaccion.WorkLifeBalance.unique()
# Out:
# array([2.  , 4.  , 1.  , 3.  , 2.76])

# %%
retiros.columns
# Out:
# Index(['EmployeeID', 'Attrition', 'retirementDate', 'retirementType',
#        'resignationReason'],
#       dtype='object')

# %%
borrarRetiros=['Attrition','retirementDate']

# %%
retiros.resignationReason.unique()
# Out:
# array(['Others', 'Stress', 'Salary', 'NR'], dtype=object)

# %% [markdown]
# Hay que hacer un Merge de todas las columnas no descartadas
